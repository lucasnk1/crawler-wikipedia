# %%
# CRAWLER 

import requests
from bs4 import BeautifulSoup
import os
import re
import asyncio
from concurrent.futures import ThreadPoolExecutor

# cria pasta pra salvar HTMLs
os.makedirs("wikipedia_pessoas", exist_ok=True)

# base da wikipedia
URL_BASE = "https://pt.wikipedia.org"
PAGINA_INICIAL = "/"

# sets e listas pra controlar
visitados = set()  # páginas que já visitamos
fila_links = set([PAGINA_INICIAL])  # links que vamos visitar
pessoas_coletadas = 0
MAX_PESSOAS = 1000
total_visitas = 0

# cabeçalho pra parecer navegador normal
cabecalhos = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
                  "(KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# função que limpa caracteres estranhos do nome do arquivo
def limpar_nome_arquivo(nome):
    return re.sub(r'[\\/*?:"<>|]', "", nome)

# função que verifica se a página parece de pessoa
def eh_pagina_de_pessoa(sopa):
    # procura a infobox da página
    infobox = sopa.find("table", class_=lambda c: (
        (isinstance(c, str) and "infobox" in c) or
        (isinstance(c, list) and any("infobox" in cls for cls in c))
    ))
    if infobox:
        rotulos = [th.get_text(strip=True).lower() for th in infobox.find_all("th")]
        rotulos_pessoa = ['nascimento', 'data de nascimento', 'ocupação',
                           'nome completo', 'nacionalidade', 'morte', 'cidadania']
        rotulos_nao_pessoa = ['localização', 'população', 'idioma', 'extinção', 'capital', 'território']
        if any(r in rotulos for r in rotulos_pessoa):
            if any(r in rotulos for r in rotulos_nao_pessoa):
                return False
            return True
    # se não tem infobox, olha categorias
    div_categorias = sopa.find("div", {"id": "mw-normal-catlinks"})
    if div_categorias:
        categorias = [li.get_text(strip=True).lower() for li in div_categorias.find_all("li")]
        palavras_pessoa = ['nascimentos', 'homens', 'mulheres', 'cantores', 'escritores', 'atores', 'políticos', 'biografia']
        if any(any(p in c for p in palavras_pessoa) for c in categorias):
            return True
    return False

# função que processa cada link (vai baixar página e salvar se for pessoa)
def processar_link(href):
    global pessoas_coletadas, total_visitas
    # se já visitamos ou coletamos tudo, sai
    if href in visitados or pessoas_coletadas >= MAX_PESSOAS:
        return []

    visitados.add(href)
    url = URL_BASE + href if href != "/" else URL_BASE + "/"
    total_visitas += 1
    print(f"{total_visitas} Visitando ({pessoas_coletadas}/{MAX_PESSOAS}): {url}")

    try:
        resp = requests.get(url, headers=cabecalhos, timeout=10)
        if resp.status_code != 200:
            return []
    except Exception as e:
        print(f"Erro na requisição: {e}")
        return []

    sopa = BeautifulSoup(resp.text, "html.parser")
    novos_links = []

    # se for página de pessoa, salva HTML
    if eh_pagina_de_pessoa(sopa) and pessoas_coletadas < MAX_PESSOAS:
        titulo = sopa.find("h1", id="firstHeading")
        nome_pessoa = limpar_nome_arquivo(titulo.text.strip()) if titulo else f"pessoa_desconhecida_{pessoas_coletadas}"
        nome_arquivo = f"wikipedia_pessoas/{nome_pessoa}.html"
        with open(nome_arquivo, "w", encoding="utf-8") as f:
            f.write(resp.text)
        pessoas_coletadas += 1

    # pega todos os links que parecem pessoas (primeira letra maiúscula e não contém ':')
    for a in sopa.find_all("a", href=True):
        h = a['href']
        if h.startswith("/wiki/") and ":" not in h and h[6].isupper() and h not in visitados:
            novos_links.append(h)

    return novos_links

# função assíncrona que coordena as threads
async def main():
    global fila_links
    NUM_THREADS = 12  # aumenta número de threads pra mais velocidade

    # executor que roda threads
    loop = asyncio.get_event_loop()
    with ThreadPoolExecutor(max_workers=NUM_THREADS) as executor:
        while pessoas_coletadas < MAX_PESSOAS and fila_links:
            # pega um lote de links pra processar em paralelo
            lote = list(fila_links)[:NUM_THREADS]
            fila_links -= set(lote)  # remove da fila os que vamos processar
            tarefas = [loop.run_in_executor(executor, processar_link, link) for link in lote]

            # espera todos terminarem
            resultados = await asyncio.gather(*tarefas)

            # adiciona novos links que não foram visitados
            for lista in resultados:
                for link in lista:
                    if link not in visitados:
                        fila_links.add(link)

# roda o crawler
import nest_asyncio
nest_asyncio.apply()
await main()

print(f"Coletadas {pessoas_coletadas} páginas de pessoas em {total_visitas} visitas.")
# Out:
# 1 Visitando (0/1000): https://pt.wikipedia.org/
# 2 Visitando (0/1000): https://pt.wikipedia.org/wiki/S%C3%A9rgio_Mendes
# 3 Visitando (0/1000): https://pt.wikipedia.org/wiki/Catarina,_Duquesa_de_Kent
# 4 Visitando (0/1000): https://pt.wikipedia.org/wiki/Giorgio_Armani
# 5 Visitando (0/1000): https://pt.wikipedia.org/wiki/Invas%C3%A3o_da_Ucr%C3%A2nia_pela_R%C3%BAssia_(2022%E2%80%93presente)
# 6 Visitando (0/1000): https://pt.wikipedia.org/wiki/Sud%C3%A3o
# 7 Visitando (0/1000): https://pt.wikipedia.org/wiki/Wikip%C3%A9dia
# 8 Visitando (0/1000): https://pt.wikipedia.org/wiki/Jacques_Charrier
# 9 Visitando (0/1000): https://pt.wikipedia.org/wiki/Bombardeios_navais_Aliados_no_Jap%C3%A3o_na_Segunda_Guerra_Mundial
# 10 Visitando (0/1000): https://pt.wikipedia.org/wiki/Arquip%C3%A9lago_japon%C3%AAs
# 11 Visitando (0/1000): https://pt.wikipedia.org/wiki/Elevador_da_Gl%C3%B3ria
# 12 Visitando (0/1000): https://pt.wikipedia.org/wiki/Jesse_James
# 13 Visitando (0/1000): https://pt.wikipedia.org/wiki/Funda%C3%A7%C3%A3o_Wikimedia
# 14 Visitando (4/1000): https://pt.wikipedia.org/wiki/World_Monuments_Fund15 Visitando (4/1000): https://pt.wikipedia.org/wiki/Guerra_Civil_na_Rep%C3%BAblica_Centro-Africana_(2012%E2%80%93presente)
# 16 Visitando (4/1000): https://pt.wikipedia.org/wiki/Ilha_Tromelin
#
# 17 Visitando (4/1000): https://pt.wikipedia.org/wiki/David_Cameron
# 18 Visitando (4/1000): https://pt.wikipedia.org/wiki/The_Hispanic_Society_of_America
# 19 Visitando (4/1000): https://pt.wikipedia.org/wiki/Bang_Bang_(telenovela)
# 20 Visitando (4/1000): https://pt.wikipedia.org/wiki/PIB
# 21 Visitando (4/1000): https://pt.wikipedia.org/wiki/Pandemia_de_COVID-19_na_Ucr%C3%A2nia
# 22 Visitando (4/1000): https://pt.wikipedia.org/wiki/Wikip%C3%A9dia_em_shoto_do_sul
# 23 Visitando (4/1000): https://pt.wikipedia.org/wiki/Presidente_da_R%C3%BAssia
# 24 Visitando (4/1000): https://pt.wikipedia.org/wiki/The_Economic_Times
# 25 Visitando (4/1000): https://pt.wikipedia.org/wiki/Tecnologia
# 26 Visitando (5/1000): https://pt.wikipedia.org/wiki/Capital_intelectual
# 27 Visitando (5/1000): https://pt.wikipedia.org/wiki/Meteorologia
# 28 Visitando (5/1000): https://pt.wikipedia.org/wiki/Polui%C3%A7%C3%A3o
# 29 Visitando (5/1000): https://pt.wikipedia.org/wiki/Presidente_da_Oss%C3%A9tia_do_Sul
# 30 Visitando (5/1000): https://pt.wikipedia.org/wiki/Corrida_do_Ouro
# 31 Visitando (5/1000): https://pt.wikipedia.org/wiki/Henry_Temple,_3.%C2%BA_Visconde_Palmerston
# 32 Visitando (5/1000): https://pt.wikipedia.org/wiki/Lista_de_primeiros-ministros_do_Paquist%C3%A3o
# 33 Visitando (5/1000): https://pt.wikipedia.org/wiki/L%C3%ADngua_khmer
# 34 Visitando (5/1000): https://pt.wikipedia.org/wiki/Donald_Trump
# 35 Visitando (5/1000): https://pt.wikipedia.org/wiki/Pandemia_de_COVID-19_em_navios_da_Marinha
# 36 Visitando (5/1000): https://pt.wikipedia.org/wiki/R%C3%BAssia_Justa
# 37 Visitando (5/1000): https://pt.wikipedia.org/wiki/Ita%C3%BA_Cultural
# 38 Visitando (8/1000): https://pt.wikipedia.org/wiki/Ric_Flair39 Visitando (8/1000): https://pt.wikipedia.org/wiki/Edward_Mills_Purcell
#
# 40 Visitando (8/1000): https://pt.wikipedia.org/wiki/Esquerda_(pol%C3%ADtica)
# 41 Visitando (8/1000): https://pt.wikipedia.org/wiki/Lilibet_de_Sussex
# 42 Visitando (8/1000): https://pt.wikipedia.org/wiki/CompartilhaIgual
# 43 Visitando (8/1000): https://pt.wikipedia.org/wiki/Cinco_for%C3%A7as_de_Porter
# 44 Visitando (8/1000): https://pt.wikipedia.org/wiki/Mali
# 45 Visitando (8/1000): https://pt.wikipedia.org/wiki/The_Sydney_Morning_Herald
# 46 Visitando (8/1000): https://pt.wikipedia.org/wiki/Universidade_da_Pensilv%C3%A2nia
# 47 Visitando (8/1000): https://pt.wikipedia.org/wiki/MS-13
# 48 Visitando (8/1000): https://pt.wikipedia.org/wiki/Rom%C3%A9nia
# 49 Visitando (8/1000): https://pt.wikipedia.org/wiki/Road_Warrior_Animal
# 50 Visitando (9/1000): https://pt.wikipedia.org/wiki/Banco_Central_Europeu
# 51 Visitando (9/1000): https://pt.wikipedia.org/wiki/Ensino_fundamental
# 52 Visitando (9/1000): https://pt.wikipedia.org/wiki/Europol
# 53 Visitando (9/1000): https://pt.wikipedia.org/wiki/Jerzy_Neyman
# 54 Visitando (9/1000): https://pt.wikipedia.org/wiki/Princeton
# 55 Visitando (9/1000): https://pt.wikipedia.org/wiki/Catarina,_Princesa_de_Gales
# 56 Visitando (9/1000): https://pt.wikipedia.org/wiki/Barragem_do_Pego_do_Altar#Ferrovia
# 57 Visitando (9/1000): https://pt.wikipedia.org/wiki/L%C3%ADngua_luxemburguesa
# 58 Visitando (9/1000): https://pt.wikipedia.org/wiki/Lista_de_bens_tombados_na_cidade_de_S%C3%A3o_Paulo
# 59 Visitando (9/1000): https://pt.wikipedia.org/wiki/Frente_Popular_para_a_Recupera%C3%A7%C3%A3o
# 60 Visitando (9/1000): https://pt.wikipedia.org/wiki/Ditadura_do_proletariado
# 61 Visitando (9/1000): https://pt.wikipedia.org/wiki/Ind%C3%BAstria_aeroespacial
# 62 Visitando (11/1000): https://pt.wikipedia.org/wiki/Assistente_de_bordo63 Visitando (11/1000): https://pt.wikipedia.org/wiki/Estado_burgu%C3%AAs
#
# 64 Visitando (11/1000): https://pt.wikipedia.org/wiki/Impalamento_(her%C3%A1ldica)
# 65 Visitando (11/1000): https://pt.wikipedia.org/wiki/Prolet%C3%A1rios_de_todos_os_pa%C3%ADses,_uni-vos!
# 66 Visitando (11/1000): https://pt.wikipedia.org/wiki/Arresto
# 67 Visitando (11/1000): https://pt.wikipedia.org/wiki/Monumento_a_Luiz_Pereira_Barreto
# 68 Visitando (11/1000): https://pt.wikipedia.org/wiki/Vila_Ol%C3%ADmpia
# 69 Visitando (11/1000): https://pt.wikipedia.org/wiki/Stanley_Norman_Cohen
# 70 Visitando (11/1000): https://pt.wikipedia.org/wiki/Linha_de_Sintra
# 71 Visitando (11/1000): https://pt.wikipedia.org/wiki/Pol%C3%ADtica_da_R%C3%BAssia
# 72 Visitando (11/1000): https://pt.wikipedia.org/wiki/ETEC_Carlos_de_Campos
# 73 Visitando (11/1000): https://pt.wikipedia.org/wiki/Companhia_das_Lez%C3%ADrias
# 74 Visitando (12/1000): https://pt.wikipedia.org/wiki/Monarquia_Constitucional75 Visitando (12/1000): https://pt.wikipedia.org/wiki/Propuls%C3%A3o_de_foguete
# 76 Visitando (12/1000): https://pt.wikipedia.org/wiki/Secretaria_de_Desenvolvimento_Urbano_e_Habita%C3%A7%C3%A3o_do_Estado_de_S%C3%A3o_Paulo
# 77 Visitando (12/1000): https://pt.wikipedia.org/wiki/Jules_Hoffmann
#
# 78 Visitando (12/1000): https://pt.wikipedia.org/wiki/Serrana
# 79 Visitando (12/1000): https://pt.wikipedia.org/wiki/Lista_dos_campe%C3%B5es_dos_Estados_Unidos_da_WWE
# 80 Visitando (12/1000): https://pt.wikipedia.org/wiki/Moedas_de_euro_neerlandesas
# 81 Visitando (12/1000): https://pt.wikipedia.org/wiki/Esta%C3%A7%C3%A3o_Ferrovi%C3%A1ria_de_Sete_Rios
# 82 Visitando (12/1000): https://pt.wikipedia.org/wiki/Gerald_Ford
# 83 Visitando (12/1000): https://pt.wikipedia.org/wiki/National_Taxonomy_of_Exempt_Entities
# 84 Visitando (12/1000): https://pt.wikipedia.org/wiki/Crise_econ%C3%B4mica_de_2008
# 85 Visitando (12/1000): https://pt.wikipedia.org/wiki/Brasil
# 86 Visitando (14/1000): https://pt.wikipedia.org/wiki/Celso_Furtado87 Visitando (14/1000): https://pt.wikipedia.org/wiki/Bill_Richardson
#
# 88 Visitando (14/1000): https://pt.wikipedia.org/wiki/Nossa_Senhora_da_Concei%C3%A7%C3%A3o_Aparecida
# 89 Visitando (14/1000): https://pt.wikipedia.org/wiki/Adlai_Stevenson_I
# 90 Visitando (14/1000): https://pt.wikipedia.org/wiki/Lista_de_concentra%C3%A7%C3%B5es_urbanas_do_Brasil_por_popula%C3%A7%C3%A3o
# 91 Visitando (14/1000): https://pt.wikipedia.org/wiki/Morte_de_Tancredo_Neves
# 92 Visitando (14/1000): https://pt.wikipedia.org/wiki/A_Justi%C3%A7a_(escultura)
# 93 Visitando (14/1000): https://pt.wikipedia.org/wiki/Satoshi_%C5%8Cmura
# 94 Visitando (14/1000): https://pt.wikipedia.org/wiki/M%C3%BAsica_popular_brasileira
# 95 Visitando (14/1000): https://pt.wikipedia.org/wiki/Thaddeus_Stevens
# 96 Visitando (14/1000): https://pt.wikipedia.org/wiki/Conven%C3%A7%C3%A3o_Americana_sobre_Direitos_Humanos
# 97 Visitando (14/1000): https://pt.wikipedia.org/wiki/Pol%C3%ADcia
# 98 Visitando (19/1000): https://pt.wikipedia.org/wiki/Jos%C3%A9_Paulo_Cavalcanti_Filho
# 99 Visitando (19/1000): https://pt.wikipedia.org/wiki/H%C3%A9lio_Langsch_Keller
# 100 Visitando (19/1000): https://pt.wikipedia.org/wiki/V%C3%ADtor_Viana
# 101 Visitando (19/1000): https://pt.wikipedia.org/wiki/Lu%C3%ADs_Roberto_Andrade_Ponte
# 102 Visitando (19/1000): https://pt.wikipedia.org/wiki/Post-britpop
# 103 Visitando (19/1000): https://pt.wikipedia.org/wiki/Elei%C3%A7%C3%B5es_estaduais_em_Minas_Gerais_em_1970
# 104 Visitando (19/1000): https://pt.wikipedia.org/wiki/Pereira_da_Silva_(poeta)
# 105 Visitando (19/1000): https://pt.wikipedia.org/wiki/Delta_(fam%C3%ADlia_de_foguetes)
# 106 Visitando (19/1000): https://pt.wikipedia.org/wiki/Tarc%C3%ADsio_Meira
# 107 Visitando (19/1000): https://pt.wikipedia.org/wiki/Parlamento_Brit%C3%A2nico
# 108 Visitando (19/1000): https://pt.wikipedia.org/wiki/Revolu%C3%A7%C3%A3o_Constitucionalista_de_1932
# 109 Visitando (19/1000): https://pt.wikipedia.org/wiki/Viaduto_do_Ch%C3%A1
# 110 Visitando (24/1000): https://pt.wikipedia.org/wiki/Montes_Claros111 Visitando (24/1000): https://pt.wikipedia.org/wiki/TV_Cultura
# 112 Visitando (24/1000): https://pt.wikipedia.org/wiki/Argemiro_de_Assis_Brasil
#
# 113 Visitando (24/1000): https://pt.wikipedia.org/wiki/Desejo_(miniss%C3%A9rie)
# 114 Visitando (24/1000): https://pt.wikipedia.org/wiki/Shopping_Light
# 115 Visitando (24/1000): https://pt.wikipedia.org/wiki/Poeta
# 116 Visitando (24/1000): https://pt.wikipedia.org/wiki/Hilda_Furac%C3%A3o_(miniss%C3%A9rie)
# 117 Visitando (24/1000): https://pt.wikipedia.org/wiki/Conflito_de_Cabinda
# 118 Visitando (24/1000): https://pt.wikipedia.org/wiki/Cassiano_Gabus_Mendes
# 119 Visitando (24/1000): https://pt.wikipedia.org/wiki/Greenville_(Carolina_do_Sul)
# 120 Visitando (24/1000): https://pt.wikipedia.org/wiki/Itapecerica_da_Serra
# 121 Visitando (24/1000): https://pt.wikipedia.org/wiki/Balan%C3%A7a_comercial
# 122 Visitando (26/1000): https://pt.wikipedia.org/wiki/TV_Clube_(Ribeir%C3%A3o_Preto)123 Visitando (26/1000): https://pt.wikipedia.org/wiki/Embu-Gua%C3%A7u
# 124 Visitando (26/1000): https://pt.wikipedia.org/wiki/Augusto_Comte
#
# 125 Visitando (26/1000): https://pt.wikipedia.org/wiki/Dom_Odilo_Scherer
# 126 Visitando (26/1000): https://pt.wikipedia.org/wiki/Bandidos_da_Falange
# 127 Visitando (26/1000): https://pt.wikipedia.org/wiki/Reuni%C3%A3o_no_Autom%C3%B3vel_Clube
# 128 Visitando (26/1000): https://pt.wikipedia.org/wiki/Mundo_da_Lua
# 129 Visitando (26/1000): https://pt.wikipedia.org/wiki/Capra
# 130 Visitando (26/1000): https://pt.wikipedia.org/wiki/Disparada
# 131 Visitando (26/1000): https://pt.wikipedia.org/wiki/Direitos_civis
# 132 Visitando (26/1000): https://pt.wikipedia.org/wiki/Sepultura
# 133 Visitando (26/1000): https://pt.wikipedia.org/wiki/Miguel_de_Unamuno
# 134 Visitando (27/1000): https://pt.wikipedia.org/wiki/Meiry_Vieira
# 135 Visitando (27/1000): https://pt.wikipedia.org/wiki/A_Hora_e_Vez_de_Augusto_Matraga
# 136 Visitando (27/1000): https://pt.wikipedia.org/wiki/Mercado_Comum_do_Sul
# 137 Visitando (27/1000): https://pt.wikipedia.org/wiki/Descobrimentos_espanh%C3%B3is
# 138 Visitando (27/1000): https://pt.wikipedia.org/wiki/Direito_do_Brasil
# 139 Visitando (27/1000): https://pt.wikipedia.org/wiki/S%C3%ADlvio_de_Abreu
# 140 Visitando (27/1000): https://pt.wikipedia.org/wiki/Rede_Brasil_Esp%C3%ADrito_Santo
# 141 Visitando (27/1000): https://pt.wikipedia.org/wiki/O_S%C3%A9timo_Guardi%C3%A3o
# 142 Visitando (27/1000): https://pt.wikipedia.org/wiki/USS_Indiana_(BB-58)
# 143 Visitando (27/1000): https://pt.wikipedia.org/wiki/Harry_Barkus_Gray
# 144 Visitando (27/1000): https://pt.wikipedia.org/wiki/Avenida_Giovanni_Gronchi
# 145 Visitando (27/1000): https://pt.wikipedia.org/wiki/Marvin_Cohen
# 146 Visitando (30/1000): https://pt.wikipedia.org/wiki/Canind%C3%A9_(bairro_de_S%C3%A3o_Paulo)
# 147 Visitando (30/1000): https://pt.wikipedia.org/wiki/L%C3%ADngua_javanesa
# 148 Visitando (30/1000): https://pt.wikipedia.org/wiki/Aumenta_Que_%C3%89_Rock%27n_Roll
# 149 Visitando (30/1000): https://pt.wikipedia.org/wiki/A%C3%ADlton_Gra%C3%A7a
# 150 Visitando (30/1000): https://pt.wikipedia.org/wiki/Meir_Wilchek
# 151 Visitando (30/1000): https://pt.wikipedia.org/wiki/Reynold_B._Johnson
# 152 Visitando (30/1000): https://pt.wikipedia.org/wiki/Manoel_Carlos
# 153 Visitando (30/1000): https://pt.wikipedia.org/wiki/Presidente_da_Turquia
# 154 Visitando (30/1000): https://pt.wikipedia.org/wiki/Regi%C3%A3o_Geogr%C3%A1fica_Imediata_de_Tatu%C3%AD
# 155 Visitando (30/1000): https://pt.wikipedia.org/wiki/Cepticismo
# 156 Visitando (30/1000): https://pt.wikipedia.org/wiki/Parque_Estadual_do_Jaragu%C3%A1
# 157 Visitando (30/1000): https://pt.wikipedia.org/wiki/Capitania_de_S%C3%A3o_Vicente
# 158 Visitando (33/1000): https://pt.wikipedia.org/wiki/Bella_Camero159 Visitando (33/1000): https://pt.wikipedia.org/wiki/Olho_no_Olho
# 160 Visitando (33/1000): https://pt.wikipedia.org/wiki/Integra%C3%A7%C3%A3o_econ%C3%B4mica_total
#
# 161 Visitando (33/1000): https://pt.wikipedia.org/wiki/Bosco_Saraiva
# 162 Visitando (33/1000): https://pt.wikipedia.org/wiki/Barra_(her%C3%A1ldica)
# 163 Visitando (33/1000): https://pt.wikipedia.org/wiki/David_Arquette
# 164 Visitando (33/1000): https://pt.wikipedia.org/wiki/Ruslan_Medzhitov
# 165 Visitando (33/1000): https://pt.wikipedia.org/wiki/Irredentismo_russo
# 166 Visitando (33/1000): https://pt.wikipedia.org/wiki/Companhia_Carris_de_Ferro_de_Lisboa
# 167 Visitando (33/1000): https://pt.wikipedia.org/wiki/Revolu%C3%A7%C3%A3o_Guatemalteca
# 168 Visitando (33/1000): https://pt.wikipedia.org/wiki/Revista_Veja
# 169 Visitando (33/1000): https://pt.wikipedia.org/wiki/Campanha_presidencial_de_Donald_Trump_em_2000
# 170 Visitando (36/1000): https://pt.wikipedia.org/wiki/Pe%C3%A7as_do_escudo_(her%C3%A1ldica)#Cotica
# 171 Visitando (36/1000): https://pt.wikipedia.org/wiki/Cartum_(Estado)
# 172 Visitando (36/1000): https://pt.wikipedia.org/wiki/Pol%C3%ADcia_judici%C3%A1ria
# 173 Visitando (36/1000): https://pt.wikipedia.org/wiki/Moedas_de_euro_andorranas
# 174 Visitando (36/1000): https://pt.wikipedia.org/wiki/Prov%C3%ADncia_do_Piau%C3%AD
# 175 Visitando (36/1000): https://pt.wikipedia.org/wiki/Joan%C3%B3polis
# 176 Visitando (36/1000): https://pt.wikipedia.org/wiki/Intelig%C3%AAncia_artificial
# 177 Visitando (36/1000): https://pt.wikipedia.org/wiki/Brito_Camacho
# 178 Visitando (36/1000): https://pt.wikipedia.org/wiki/Thobias_da_Vai-Vai
# 179 Visitando (36/1000): https://pt.wikipedia.org/wiki/Garimpo
# 180 Visitando (36/1000): https://pt.wikipedia.org/wiki/Tortura_no_Brasil
# 181 Visitando (36/1000): https://pt.wikipedia.org/wiki/Res%C3%ADduos_s%C3%B3lidos_urbanos
# 182 Visitando (37/1000): https://pt.wikipedia.org/wiki/Lista_de_massacres_e_rebeli%C3%B5es_prisionais_no_Brasil183 Visitando (37/1000): https://pt.wikipedia.org/wiki/Extrema
# 184 Visitando (37/1000): https://pt.wikipedia.org/wiki/Aquilino_Ribeiro
# 185 Visitando (37/1000): https://pt.wikipedia.org/wiki/Tropical_de_altitude
# 186 Visitando (37/1000): https://pt.wikipedia.org/wiki/Vivo
#
# 187 Visitando (37/1000): https://pt.wikipedia.org/wiki/Desigualdade_regional_no_Brasil
# 188 Visitando (37/1000): https://pt.wikipedia.org/wiki/Polui%C3%A7%C3%A3o_por_merc%C3%BArio
# 189 Visitando (37/1000): https://pt.wikipedia.org/wiki/Pulm%C3%B5es
# 190 Visitando (37/1000): https://pt.wikipedia.org/wiki/Confer%C3%AAncia_Ibero-americana
# 191 Visitando (37/1000): https://pt.wikipedia.org/wiki/Campeonato_Alem%C3%A3o_de_Futebol
# 192 Visitando (37/1000): https://pt.wikipedia.org/wiki/Retratos_oficiais_de_Donald_Trump
# 193 Visitando (37/1000): https://pt.wikipedia.org/wiki/Royal_Rumble_(2012)
# 194 Visitando (38/1000): https://pt.wikipedia.org/wiki/WWE_The_Shield%27s_Final_Chapter195 Visitando (38/1000): https://pt.wikipedia.org/wiki/Campeonato_Turco_de_Futebol
#
# 196 Visitando (38/1000): https://pt.wikipedia.org/wiki/Guilherme_Blest_Gana
# 197 Visitando (38/1000): https://pt.wikipedia.org/wiki/Universidade_da_Calif%C3%B3rnia
# 198 Visitando (38/1000): https://pt.wikipedia.org/wiki/Lista_de_portos_do_Brasil
# 199 Visitando (38/1000): https://pt.wikipedia.org/wiki/Guerra_do_Kivu
# 200 Visitando (38/1000): https://pt.wikipedia.org/wiki/Moinhos_de_Vento_(miniss%C3%A9rie)
# 201 Visitando (38/1000): https://pt.wikipedia.org/wiki/Islamismo
# 202 Visitando (38/1000): https://pt.wikipedia.org/wiki/Chefes_de_governo
# 203 Visitando (38/1000): https://pt.wikipedia.org/wiki/Pol%C3%ADtica_externa_do_governo_Donald_Trump
# 204 Visitando (38/1000): https://pt.wikipedia.org/wiki/Regi%C3%A3o_Metropolitana_de_S%C3%A3o_Jos%C3%A9_do_Rio_Preto
# 205 Visitando (38/1000): https://pt.wikipedia.org/wiki/Pensamento
# 206 Visitando (38/1000): https://pt.wikipedia.org/wiki/Imp%C3%A9rio_Ab%C3%A1ssida207 Visitando (38/1000): https://pt.wikipedia.org/wiki/Zona_Costeira_Brasileira
# 208 Visitando (38/1000): https://pt.wikipedia.org/wiki/Dinastia_Song
#
# 209 Visitando (38/1000): https://pt.wikipedia.org/wiki/C%C3%A2mara_dos_Representantes_do_Chipre
# 210 Visitando (38/1000): https://pt.wikipedia.org/wiki/Fred_Ottman
# 211 Visitando (38/1000): https://pt.wikipedia.org/wiki/Conservapedia
# 212 Visitando (38/1000): https://pt.wikipedia.org/wiki/Socorro_(distrito_de_S%C3%A3o_Paulo)
# 213 Visitando (38/1000): https://pt.wikipedia.org/wiki/Bruce_Babbitt
# 214 Visitando (38/1000): https://pt.wikipedia.org/wiki/Andrea_Neves_da_Cunha
# 215 Visitando (38/1000): https://pt.wikipedia.org/wiki/Jane_Goodall
# 216 Visitando (38/1000): https://pt.wikipedia.org/wiki/Parque_do_Carmo
# 217 Visitando (38/1000): https://pt.wikipedia.org/wiki/Sistema_de_Informa%C3%A7%C3%A3o_sobre_Vistos
# 218 Visitando (40/1000): https://pt.wikipedia.org/wiki/Zhu_Yu_(autor)219 Visitando (40/1000): https://pt.wikipedia.org/wiki/Imp%C3%A9rio_Pala
# 220 Visitando (40/1000): https://pt.wikipedia.org/wiki/Imp%C3%A9rio_Isl%C3%A2mico
# 221 Visitando (40/1000): https://pt.wikipedia.org/wiki/Col%C3%B3nia
# 222 Visitando (40/1000): https://pt.wikipedia.org/wiki/Yves_Bonnefoy
# 223 Visitando (40/1000): https://pt.wikipedia.org/wiki/North_Wales
# 224 Visitando (40/1000): https://pt.wikipedia.org/wiki/Muhammad_Ali_Bogra
# 225 Visitando (40/1000): https://pt.wikipedia.org/wiki/Infraestrutura_de_Mato_Grosso_do_Sul#Transporte
#
# 226 Visitando (40/1000): https://pt.wikipedia.org/wiki/Google_Busca
# 227 Visitando (40/1000): https://pt.wikipedia.org/wiki/Anarquismo_social
# 228 Visitando (40/1000): https://pt.wikipedia.org/wiki/Depopula%C3%A7%C3%A3o
# 229 Visitando (40/1000): https://pt.wikipedia.org/wiki/Identidade
# 230 Visitando (42/1000): https://pt.wikipedia.org/wiki/Montgomeryville_(Pensilv%C3%A2nia)231 Visitando (42/1000): https://pt.wikipedia.org/wiki/Severino_di_Giovanni
# 232 Visitando (42/1000): https://pt.wikipedia.org/wiki/Google_Livros
# 233 Visitando (42/1000): https://pt.wikipedia.org/wiki/AltaVista
#
# 234 Visitando (42/1000): https://pt.wikipedia.org/wiki/Google_Directory
# 235 Visitando (42/1000): https://pt.wikipedia.org/wiki/Google_Classroom
# 236 Visitando (42/1000): https://pt.wikipedia.org/wiki/G_Suite
# 237 Visitando (42/1000): https://pt.wikipedia.org/wiki/Municipalismo
# 238 Visitando (42/1000): https://pt.wikipedia.org/wiki/Tup%C3%A3
# 239 Visitando (42/1000): https://pt.wikipedia.org/wiki/Bruce_Willis
# 240 Visitando (42/1000): https://pt.wikipedia.org/wiki/Ilie_Bolojan
# 241 Visitando (42/1000): https://pt.wikipedia.org/wiki/Dinorah_de_Assis
# 242 Visitando (45/1000): https://pt.wikipedia.org/wiki/Manuel_Pardi%C3%B1as243 Visitando (45/1000): https://pt.wikipedia.org/wiki/Jos%C3%A9_F%C3%A9lix_Uriburu
# 244 Visitando (45/1000): https://pt.wikipedia.org/wiki/Rom%C3%A3ozinho
#
# 245 Visitando (45/1000): https://pt.wikipedia.org/wiki/Benjamin_de_Almeida_Sodr%C3%A9
# 246 Visitando (45/1000): https://pt.wikipedia.org/wiki/GRASP
# 247 Visitando (45/1000): https://pt.wikipedia.org/wiki/Homero_Santos
# 248 Visitando (45/1000): https://pt.wikipedia.org/wiki/Amambai
# 249 Visitando (45/1000): https://pt.wikipedia.org/wiki/L%C3%ADngua_croata
# 250 Visitando (45/1000): https://pt.wikipedia.org/wiki/Aprendizado
# 251 Visitando (45/1000): https://pt.wikipedia.org/wiki/Comunismo
# 252 Visitando (45/1000): https://pt.wikipedia.org/wiki/Viaduto_Santa_Ifig%C3%AAnia
# 253 Visitando (45/1000): https://pt.wikipedia.org/wiki/Esquerda_antistalinista
# 254 Visitando (49/1000): https://pt.wikipedia.org/wiki/Nikolai_Bukharin
# 255 Visitando (49/1000): https://pt.wikipedia.org/wiki/Monthly_Review
# 256 Visitando (49/1000): https://pt.wikipedia.org/wiki/Am%C3%ADlcar_Cabral
# 257 Visitando (49/1000): https://pt.wikipedia.org/wiki/Susan_Sontag
# 258 Visitando (49/1000): https://pt.wikipedia.org/wiki/Treinadores_do_Paysandu_Sport_Club
# 259 Visitando (49/1000): https://pt.wikipedia.org/wiki/Consola%C3%A7%C3%A3o_(distrito_de_S%C3%A3o_Paulo)
# 260 Visitando (49/1000): https://pt.wikipedia.org/wiki/Ci%C3%AAncia_pol%C3%ADtica
# 261 Visitando (49/1000): https://pt.wikipedia.org/wiki/Arquitetura_colonial_portuguesa
# 262 Visitando (49/1000): https://pt.wikipedia.org/wiki/Avenida_S%C3%A3o_Lu%C3%ADs
# 263 Visitando (49/1000): https://pt.wikipedia.org/wiki/Europa_meridional
# 264 Visitando (49/1000): https://pt.wikipedia.org/wiki/Ricardo_Macchi
# 265 Visitando (49/1000): https://pt.wikipedia.org/wiki/Kidal_(Regi%C3%A3o)
# 266 Visitando (53/1000): https://pt.wikipedia.org/wiki/Timor_portugu%C3%AAs
# 267 Visitando (53/1000): https://pt.wikipedia.org/wiki/Anti-guerra
# 268 Visitando (53/1000): https://pt.wikipedia.org/wiki/Mindelo_(Cabo_Verde)
# 269 Visitando (53/1000): https://pt.wikipedia.org/wiki/National_Book_Award
# 270 Visitando (53/1000): https://pt.wikipedia.org/wiki/Economia_p%C3%B3s-escassez
# 271 Visitando (53/1000): https://pt.wikipedia.org/wiki/DoubleClick
# 272 Visitando (53/1000): https://pt.wikipedia.org/wiki/Esta%C3%A7%C3%A3o_Ferrovi%C3%A1ria_de_Pa%C3%A7o_de_Arcos
# 273 Visitando (53/1000): https://pt.wikipedia.org/wiki/Dinastia_Tang
# 274 Visitando (53/1000): https://pt.wikipedia.org/wiki/TV_R%C3%A1-Tim-Bum
# 275 Visitando (53/1000): https://pt.wikipedia.org/wiki/O_Auto_da_Compadecida_(miniss%C3%A9rie)
# 276 Visitando (53/1000): https://pt.wikipedia.org/wiki/Alucina%C3%A7%C3%A3o_(intelig%C3%AAncia_artificial)
# 277 Visitando (53/1000): https://pt.wikipedia.org/wiki/Miss_USA
# 278 Visitando (53/1000): https://pt.wikipedia.org/wiki/Gary_(Indiana)279 Visitando (53/1000): https://pt.wikipedia.org/wiki/Telecine_Action
#
# 280 Visitando (53/1000): https://pt.wikipedia.org/wiki/Lifetime_(canal_de_televis%C3%A3o)
# 281 Visitando (53/1000): https://pt.wikipedia.org/wiki/Mashable
# 282 Visitando (53/1000): https://pt.wikipedia.org/wiki/Ilhas_Adjacentes
# 283 Visitando (53/1000): https://pt.wikipedia.org/wiki/Biloxi_(Mississippi)
# 284 Visitando (53/1000): https://pt.wikipedia.org/wiki/Segunda_Resid%C3%AAncia_de_Vilanova_Artigas
# 285 Visitando (53/1000): https://pt.wikipedia.org/wiki/Franc_Rod%C3%A9
# 286 Visitando (53/1000): https://pt.wikipedia.org/wiki/Annie_Leibovitz
# 287 Visitando (53/1000): https://pt.wikipedia.org/wiki/Retorno,_Reclama%C3%A7%C3%A3o_e_Reabilita%C3%A7%C3%A3o
# 288 Visitando (53/1000): https://pt.wikipedia.org/wiki/War_Democrats
# 289 Visitando (53/1000): https://pt.wikipedia.org/wiki/Sistema
# 290 Visitando (54/1000): https://pt.wikipedia.org/wiki/Felix_the_Cat291 Visitando (54/1000): https://pt.wikipedia.org/wiki/Condado_de_Tippah
#
# 292 Visitando (54/1000): https://pt.wikipedia.org/wiki/Talk_shows
# 293 Visitando (54/1000): https://pt.wikipedia.org/wiki/EBC
# 294 Visitando (54/1000): https://pt.wikipedia.org/wiki/Rupert_(s%C3%A9rie)
# 295 Visitando (54/1000): https://pt.wikipedia.org/wiki/Via_L%C3%A1ctea
# 296 Visitando (54/1000): https://pt.wikipedia.org/wiki/Nomadismo
# 297 Visitando (54/1000): https://pt.wikipedia.org/wiki/Tentativa_de_golpe_de_Estado_na_Uni%C3%A3o_Sovi%C3%A9tica_em_1991
# 298 Visitando (54/1000): https://pt.wikipedia.org/wiki/Grzegorz_Ry%C5%9B
# 299 Visitando (54/1000): https://pt.wikipedia.org/wiki/Conforto_ambiental
# 300 Visitando (54/1000): https://pt.wikipedia.org/wiki/Labrador
# 301 Visitando (54/1000): https://pt.wikipedia.org/wiki/Coraz%C3%B3n_Aquino
# 302 Visitando (56/1000): https://pt.wikipedia.org/wiki/Novo_pensamento_pol%C3%ADtico303 Visitando (56/1000): https://pt.wikipedia.org/wiki/Preto
# 304 Visitando (56/1000): https://pt.wikipedia.org/wiki/Pen%C3%ADnsula_de_Labrador
# 305 Visitando (56/1000): https://pt.wikipedia.org/wiki/Rep%C3%BAblica_Popular_da_Bulg%C3%A1ria#Fim_do_regime
# 306 Visitando (56/1000): https://pt.wikipedia.org/wiki/Aglomerado_aberto
#
# 307 Visitando (56/1000): https://pt.wikipedia.org/wiki/Divis%C3%A3o_N.%C2%BA_2_(Terra_Nova_e_Labrador)
# 308 Visitando (56/1000): https://pt.wikipedia.org/wiki/Martus_Tavares
# 309 Visitando (56/1000): https://pt.wikipedia.org/wiki/TV_Templo
# 310 Visitando (56/1000): https://pt.wikipedia.org/wiki/Abdica%C3%A7%C3%A3o_de_Pedro_I_do_Brasil
# 311 Visitando (56/1000): https://pt.wikipedia.org/wiki/Harvill_Secker
# 312 Visitando (56/1000): https://pt.wikipedia.org/wiki/Wikip%C3%A9dia_em_arpitano
# 313 Visitando (56/1000): https://pt.wikipedia.org/wiki/Grupo_Barraqueiro#J._J._Santo_António_/_Isidoro_Duarte_/_Henrique_Leonardo_Mota
# 314 Visitando (56/1000): https://pt.wikipedia.org/wiki/O_Rep%C3%BAblico315 Visitando (56/1000): https://pt.wikipedia.org/wiki/NGC_3603
#
# 316 Visitando (56/1000): https://pt.wikipedia.org/wiki/Marcelo_Crivella
# 317 Visitando (56/1000): https://pt.wikipedia.org/wiki/Antonio_Bulh%C3%B5es
# 318 Visitando (56/1000): https://pt.wikipedia.org/wiki/Condado_de_Pearl_River
# 319 Visitando (56/1000): https://pt.wikipedia.org/wiki/Cormac_McCarthy
# 320 Visitando (56/1000): https://pt.wikipedia.org/wiki/Pedreira_(distrito_de_S%C3%A3o_Paulo)
# 321 Visitando (56/1000): https://pt.wikipedia.org/wiki/Tropicalismo
# 322 Visitando (56/1000): https://pt.wikipedia.org/wiki/Lu%C3%ADsa_Margarida_da_Pr%C3%BAssia
# 323 Visitando (56/1000): https://pt.wikipedia.org/wiki/Oposi%C3%A7%C3%A3o_%C3%A0_imigra%C3%A7%C3%A3o
# 324 Visitando (56/1000): https://pt.wikipedia.org/wiki/Nova_Ind%C3%BAstria_Brasil
# 325 Visitando (56/1000): https://pt.wikipedia.org/wiki/Colobus
# 326 Visitando (60/1000): https://pt.wikipedia.org/wiki/Literatura_barroca_no_Brasil327 Visitando (60/1000): https://pt.wikipedia.org/wiki/Conselho_Nacional_de_Desenvolvimento_Industrial
# 328 Visitando (60/1000): https://pt.wikipedia.org/wiki/Fotografia_no_Brasil
#
# 329 Visitando (60/1000): https://pt.wikipedia.org/wiki/Jos%C3%A9_Le%C3%B4nidas_Menezes_Cristino
# 330 Visitando (60/1000): https://pt.wikipedia.org/wiki/Rio_Tiet%C3%AA
# 331 Visitando (60/1000): https://pt.wikipedia.org/wiki/Claire_da_B%C3%A9lgica
# 332 Visitando (60/1000): https://pt.wikipedia.org/wiki/Porto_de_S%C3%A3o_Sebasti%C3%A3o
# 333 Visitando (60/1000): https://pt.wikipedia.org/wiki/Emocional
# 334 Visitando (60/1000): https://pt.wikipedia.org/wiki/Cedric_Alexander
# 335 Visitando (60/1000): https://pt.wikipedia.org/wiki/Hist%C3%B3ria_do_teatro_musical_no_Brasil
# 336 Visitando (60/1000): https://pt.wikipedia.org/wiki/Governo_Lula_(2023%E2%80%93presente)
# 337 Visitando (60/1000): https://pt.wikipedia.org/wiki/Jurista
# 338 Visitando (62/1000): https://pt.wikipedia.org/wiki/Piratas_do_Tiet%C3%AA339 Visitando (62/1000): https://pt.wikipedia.org/wiki/Baixada_Fluminense
#
# 340 Visitando (62/1000): https://pt.wikipedia.org/wiki/Revista_VEJA
# 341 Visitando (62/1000): https://pt.wikipedia.org/wiki/A_Bela_e_a_Fera_(musical)
# 342 Visitando (62/1000): https://pt.wikipedia.org/wiki/Supercard_of_Honor_VII
# 343 Visitando (62/1000): https://pt.wikipedia.org/wiki/Aeroporto_Internacional_do_Rio_de_Janeiro-Gale%C3%A3o
# 344 Visitando (62/1000): https://pt.wikipedia.org/wiki/Ianom%C3%A2mi
# 345 Visitando (62/1000): https://pt.wikipedia.org/wiki/Opera%C3%A7%C3%A3o_Satiagraha
# 346 Visitando (62/1000): https://pt.wikipedia.org/wiki/Rio_S%C3%A3o_Louren%C3%A7o_(S%C3%A3o_Paulo)
# 347 Visitando (62/1000): https://pt.wikipedia.org/wiki/Imagem_por_ress%C3%B4nancia_magn%C3%A9tica_funcional
# 348 Visitando (62/1000): https://pt.wikipedia.org/wiki/Programa_Casa_Verde_e_Amarela
# 349 Visitando (62/1000): https://pt.wikipedia.org/wiki/Descodifica%C3%A7%C3%A3o
# 350 Visitando (63/1000): https://pt.wikipedia.org/wiki/Aeroporto_Internacional_de_Bras%C3%ADlia
# 351 Visitando (63/1000): https://pt.wikipedia.org/wiki/Religi%C3%B5es_de_matriz_africana
# 352 Visitando (63/1000): https://pt.wikipedia.org/wiki/The_Sound_of_Music
# 353 Visitando (63/1000): https://pt.wikipedia.org/wiki/Amondauas
# 354 Visitando (63/1000): https://pt.wikipedia.org/wiki/Monogamia
# 355 Visitando (63/1000): https://pt.wikipedia.org/wiki/Air_France
# 356 Visitando (63/1000): https://pt.wikipedia.org/wiki/LOT_Polish_Airlines
# 357 Visitando (63/1000): https://pt.wikipedia.org/wiki/The_American_Wolves
# 358 Visitando (63/1000): https://pt.wikipedia.org/wiki/Lockheed_Corporation
# 359 Visitando (63/1000): https://pt.wikipedia.org/wiki/Runoko_Rashidi
# 360 Visitando (63/1000): https://pt.wikipedia.org/wiki/Noites_do_Sert%C3%A3o_(filme)
# 361 Visitando (63/1000): https://pt.wikipedia.org/wiki/Pune
# 362 Visitando (66/1000): https://pt.wikipedia.org/wiki/Austral_L%C3%ADneas_A%C3%A9reas363 Visitando (66/1000): https://pt.wikipedia.org/wiki/Reino_do_Daom%C3%A9
# 364 Visitando (66/1000): https://pt.wikipedia.org/wiki/Triple_Crown_Championship#Ring_of_Honor
#
# 365 Visitando (66/1000): https://pt.wikipedia.org/wiki/Endogamia
# 366 Visitando (66/1000): https://pt.wikipedia.org/wiki/Gladiador_(filme)
# 367 Visitando (66/1000): https://pt.wikipedia.org/wiki/Richard_Haydn
# 368 Visitando (66/1000): https://pt.wikipedia.org/wiki/Shandong_Airlines
# 369 Visitando (66/1000): https://pt.wikipedia.org/wiki/Airbus
# 370 Visitando (66/1000): https://pt.wikipedia.org/wiki/Cronologia_dos_esportes_do_Brasil
# 371 Visitando (66/1000): https://pt.wikipedia.org/wiki/Laureados_com_o_Pr%C3%AAmio_Pr%C3%ADncipe_Mahidol
# 372 Visitando (66/1000): https://pt.wikipedia.org/wiki/Revolu%C3%A7%C3%B5es_coloridas
# 373 Visitando (66/1000): https://pt.wikipedia.org/wiki/Temporada_do_Paysandu_Sport_Club_de_2023
# 374 Visitando (67/1000): https://pt.wikipedia.org/wiki/Crucifica%C3%A7%C3%A3o375 Visitando (67/1000): https://pt.wikipedia.org/wiki/Ciberativismo
# 376 Visitando (67/1000): https://pt.wikipedia.org/wiki/Vinci_(grupo)
#
# 377 Visitando (67/1000): https://pt.wikipedia.org/wiki/Bola_de_Fogo
# 378 Visitando (67/1000): https://pt.wikipedia.org/wiki/Cotonu
# 379 Visitando (67/1000): https://pt.wikipedia.org/wiki/Campeonato_Brasileiro_de_Futebol_de_2023_-_S%C3%A9rie_C
# 380 Visitando (67/1000): https://pt.wikipedia.org/wiki/Reprodu%C3%A7%C3%A3o_sexuada
# 381 Visitando (67/1000): https://pt.wikipedia.org/wiki/Doblete
# 382 Visitando (67/1000): https://pt.wikipedia.org/wiki/Saint-Gobain
# 383 Visitando (67/1000): https://pt.wikipedia.org/wiki/WWE_Books
# 384 Visitando (67/1000): https://pt.wikipedia.org/wiki/Erwin_Chargaff
# 385 Visitando (67/1000): https://pt.wikipedia.org/wiki/Empresa_privada
# 386 Visitando (68/1000): https://pt.wikipedia.org/wiki/Forbes_(magazine)387 Visitando (68/1000): https://pt.wikipedia.org/wiki/G%C3%B3nada
# 388 Visitando (68/1000): https://pt.wikipedia.org/wiki/Highway_401
#
# 389 Visitando (68/1000): https://pt.wikipedia.org/wiki/Elei%C3%A7%C3%B5es_estaduais_em_Mato_Grosso_em_1970
# 390 Visitando (68/1000): https://pt.wikipedia.org/wiki/Jean_Jacques_Dessalines
# 391 Visitando (68/1000): https://pt.wikipedia.org/wiki/Laurindo_Lalo_Leal_Filho
# 392 Visitando (68/1000): https://pt.wikipedia.org/wiki/Provo_(movimento)393 Visitando (68/1000): https://pt.wikipedia.org/wiki/Rio_Cotia
#
# 394 Visitando (68/1000): https://pt.wikipedia.org/wiki/L%C3%ADnguas_caribes
# 395 Visitando (68/1000): https://pt.wikipedia.org/wiki/Casa_Claudia
# 396 Visitando (68/1000): https://pt.wikipedia.org/wiki/Nova_Gales_do_Sul
# 397 Visitando (68/1000): https://pt.wikipedia.org/wiki/Hospital_(telenovela)
# 398 Visitando (70/1000): https://pt.wikipedia.org/wiki/L%C3%ADngua_trumai399 Visitando (70/1000): https://pt.wikipedia.org/wiki/Camomila_e_Bem-me-quer
#
# 400 Visitando (70/1000): https://pt.wikipedia.org/wiki/Jornal_de_Letras,_Artes_e_Ideias
# 401 Visitando (70/1000): https://pt.wikipedia.org/wiki/L%C3%ADnguas_guahibo
# 402 Visitando (70/1000): https://pt.wikipedia.org/wiki/Jaques_Lagoa
# 403 Visitando (70/1000): https://pt.wikipedia.org/wiki/O_Jardineiro_Espanhol_(telenovela)
# 404 Visitando (70/1000): https://pt.wikipedia.org/wiki/O_Pecado_de_Cada_Um
# 405 Visitando (70/1000): https://pt.wikipedia.org/wiki/Testemunha
# 406 Visitando (70/1000): https://pt.wikipedia.org/wiki/Ti_Ti_Ti_(2010)
# 407 Visitando (70/1000): https://pt.wikipedia.org/wiki/Confedera%C3%A7%C3%A3o
# 408 Visitando (70/1000): https://pt.wikipedia.org/wiki/Johann_Most
# 409 Visitando (70/1000): https://pt.wikipedia.org/wiki/Boy_band
# 410 Visitando (73/1000): https://pt.wikipedia.org/wiki/Westlife411 Visitando (73/1000): https://pt.wikipedia.org/wiki/Geladeira
#
# 412 Visitando (73/1000): https://pt.wikipedia.org/wiki/Quer%C3%AAncia
# 413 Visitando (73/1000): https://pt.wikipedia.org/wiki/Ti_Ti_Ti_(trilha_sonora_de_2010)
# 414 Visitando (73/1000): https://pt.wikipedia.org/wiki/Problema_angl%C3%B3fono_nos_Camar%C3%B5es
# 415 Visitando (73/1000): https://pt.wikipedia.org/wiki/South_China_Morning_Post
# 416 Visitando (73/1000): https://pt.wikipedia.org/wiki/Ubatuba
# 417 Visitando (73/1000): https://pt.wikipedia.org/wiki/Fernando_Collor
# 418 Visitando (73/1000): https://pt.wikipedia.org/wiki/Depress%C3%A3o_nervosa
# 419 Visitando (73/1000): https://pt.wikipedia.org/wiki/Rep%C3%BAblica_dos_Assassinos
# 420 Visitando (73/1000): https://pt.wikipedia.org/wiki/Franklin_Pierce
# 421 Visitando (73/1000): https://pt.wikipedia.org/wiki/Pr%C3%AAmio_Israel
# 422 Visitando (75/1000): https://pt.wikipedia.org/wiki/Humanidades423 Visitando (75/1000): https://pt.wikipedia.org/wiki/Divaldo_Suruagy
#
# 424 Visitando (75/1000): https://pt.wikipedia.org/wiki/Gabino_Besouro
# 425 Visitando (75/1000): https://pt.wikipedia.org/wiki/Ronaldo_Lessa
# 426 Visitando (75/1000): https://pt.wikipedia.org/wiki/Iraj%C3%A1_Abreu
# 427 Visitando (75/1000): https://pt.wikipedia.org/wiki/Rog%C3%A9rio_Carvalho
# 428 Visitando (75/1000): https://pt.wikipedia.org/wiki/Estimulantes
# 429 Visitando (75/1000): https://pt.wikipedia.org/wiki/Festival_de_Cartagena
# 430 Visitando (75/1000): https://pt.wikipedia.org/wiki/Disgrafia
# 431 Visitando (75/1000): https://pt.wikipedia.org/wiki/Flying_Without_Wings
# 432 Visitando (75/1000): https://pt.wikipedia.org/wiki/Refrigerante
# 433 Visitando (75/1000): https://pt.wikipedia.org/wiki/Porta-avi%C3%B5es
# 434 Visitando (80/1000): https://pt.wikipedia.org/wiki/Sociolingu%C3%ADstica435 Visitando (80/1000): https://pt.wikipedia.org/wiki/Ivan_de_Sousa_Mendes
# 436 Visitando (80/1000): https://pt.wikipedia.org/wiki/Genie_in_a_Bottle
#
# 437 Visitando (80/1000): https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_da_Am%C3%A9rica_do_Sul_por_PIB_per_capita
# 438 Visitando (80/1000): https://pt.wikipedia.org/wiki/Via%C3%A7%C3%A3o_Cruzeiro_do_Sul
# 439 Visitando (80/1000): https://pt.wikipedia.org/wiki/Magnum_opus
# 440 Visitando (80/1000): https://pt.wikipedia.org/wiki/Black_Rio
# 441 Visitando (80/1000): https://pt.wikipedia.org/wiki/Gary_Cooper
# 442 Visitando (80/1000): https://pt.wikipedia.org/wiki/Virol
# 443 Visitando (80/1000): https://pt.wikipedia.org/wiki/Coliseu_de_Roma
# 444 Visitando (80/1000): https://pt.wikipedia.org/wiki/Eliziane_Gama
# 445 Visitando (80/1000): https://pt.wikipedia.org/wiki/Paiagu%C3%A1s
# 446 Visitando (83/1000): https://pt.wikipedia.org/wiki/The_March_of_Time447 Visitando (83/1000): https://pt.wikipedia.org/wiki/Paul_Lukas
# 448 Visitando (83/1000): https://pt.wikipedia.org/wiki/Kevin_Brownlow
#
# 449 Visitando (83/1000): https://pt.wikipedia.org/wiki/Santa_Maria_degli_Angeli_e_dei_Martiri
# 450 Visitando (83/1000): https://pt.wikipedia.org/wiki/Etta_James
# 451 Visitando (83/1000): https://pt.wikipedia.org/wiki/Fontana_di_Trevi
# 452 Visitando (83/1000): https://pt.wikipedia.org/wiki/Butim
# 453 Visitando (83/1000): https://pt.wikipedia.org/wiki/Pragm%C3%A1tica
# 454 Visitando (83/1000): https://pt.wikipedia.org/wiki/Governo_de_coaliz%C3%A3o
# 455 Visitando (83/1000): https://pt.wikipedia.org/wiki/Anast%C3%A1cio_(Mato_Grosso_do_Sul)
# 456 Visitando (83/1000): https://pt.wikipedia.org/wiki/Sele%C3%A7%C3%A3o_adversa
# 457 Visitando (83/1000): https://pt.wikipedia.org/wiki/Mina_naval
# 458 Visitando (85/1000): https://pt.wikipedia.org/wiki/Charlie_Parker
# 459 Visitando (85/1000): https://pt.wikipedia.org/wiki/Casa_dos_Artistas
# 460 Visitando (85/1000): https://pt.wikipedia.org/wiki/Merchandising
# 461 Visitando (85/1000): https://pt.wikipedia.org/wiki/Djoliba_AC
# 462 Visitando (85/1000): https://pt.wikipedia.org/wiki/Rela%C3%A7%C3%B5es_entre_Brasil_e_R%C3%BAssia
# 463 Visitando (85/1000): https://pt.wikipedia.org/wiki/C%C3%B3digo_postal
# 464 Visitando (85/1000): https://pt.wikipedia.org/wiki/Mostrativo
# 465 Visitando (85/1000): https://pt.wikipedia.org/wiki/Commodity
# 466 Visitando (85/1000): https://pt.wikipedia.org/wiki/Heinz_von_Foerster
# 467 Visitando (85/1000): https://pt.wikipedia.org/wiki/John_Logan
# 468 Visitando (85/1000): https://pt.wikipedia.org/wiki/Urso-europeu
# 469 Visitando (85/1000): https://pt.wikipedia.org/wiki/Dick_Clark
# 470 Visitando (87/1000): https://pt.wikipedia.org/wiki/Lista_Vermelha_da_IUCN471 Visitando (87/1000): https://pt.wikipedia.org/wiki/Sporting_Clube_de_Portugal
# 472 Visitando (87/1000): https://pt.wikipedia.org/wiki/Administra%C3%A7%C3%A3o_financeira
#
# 473 Visitando (87/1000): https://pt.wikipedia.org/wiki/John_Barry
# 474 Visitando (87/1000): https://pt.wikipedia.org/wiki/Tropa_de_Elite
# 475 Visitando (87/1000): https://pt.wikipedia.org/wiki/Meredith_Vieira
# 476 Visitando (87/1000): https://pt.wikipedia.org/wiki/Rela%C3%A7%C3%B5es_entre_Brasil_e_Peru
# 477 Visitando (87/1000): https://pt.wikipedia.org/wiki/Voo_din%C3%A2mico
# 478 Visitando (87/1000): https://pt.wikipedia.org/wiki/Paralouatta
# 479 Visitando (87/1000): https://pt.wikipedia.org/wiki/Roberto_Carlos_em_Detalhes
# 480 Visitando (87/1000): https://pt.wikipedia.org/wiki/Premier_League_Russa
# 481 Visitando (87/1000): https://pt.wikipedia.org/wiki/Miss_Arizona_USA
# 482 Visitando (87/1000): https://pt.wikipedia.org/wiki/Jay_Livingston483 Visitando (87/1000): https://pt.wikipedia.org/wiki/Anne_Dudley
# 484 Visitando (87/1000): https://pt.wikipedia.org/wiki/Sport_Benfica_e_Castelo_Branco
# 485 Visitando (87/1000): https://pt.wikipedia.org/wiki/Decl%C3%ADnio_contempor%C3%A2neo_da_biodiversidade_mundial
# 486 Visitando (87/1000): https://pt.wikipedia.org/wiki/FC_Zenit_St._Petersburg
# 487 Visitando (87/1000): https://pt.wikipedia.org/wiki/Guerra_da_Tr%C3%ADplice_Alian%C3%A7a
#
# 488 Visitando (87/1000): https://pt.wikipedia.org/wiki/A_Miss%C3%A3o
# 489 Visitando (87/1000): https://pt.wikipedia.org/wiki/Atl%C3%A9tico_Clube_de_Portugal
# 490 Visitando (87/1000): https://pt.wikipedia.org/wiki/Europeus
# 491 Visitando (87/1000): https://pt.wikipedia.org/wiki/Ring_name
# 492 Visitando (87/1000): https://pt.wikipedia.org/wiki/Cronologia_da_pandemia_de_COVID-19_em_janeiro_de_2022
# 493 Visitando (87/1000): https://pt.wikipedia.org/wiki/Revanchismo_franc%C3%AAs
# 494 Visitando (87/1000): https://pt.wikipedia.org/wiki/Corrientes_(prov%C3%ADncia)495 Visitando (87/1000): https://pt.wikipedia.org/wiki/Fahrenheit_9/11
#
# 496 Visitando (87/1000): https://pt.wikipedia.org/wiki/Floresta_prim%C3%A1ria
# 497 Visitando (87/1000): https://pt.wikipedia.org/wiki/Erythrocebus
# 498 Visitando (87/1000): https://pt.wikipedia.org/wiki/Vac%C3%A2ncia_da_Presid%C3%AAncia_do_Brasil_em_1964
# 499 Visitando (87/1000): https://pt.wikipedia.org/wiki/The_Lion_King_(Musical)
# 500 Visitando (87/1000): https://pt.wikipedia.org/wiki/Conven%C3%A7%C3%A3o_Nacional_do_Partido_Republicano_(Estados_Unidos)_de_2016
# 501 Visitando (87/1000): https://pt.wikipedia.org/wiki/OpenCorporates
# 502 Visitando (87/1000): https://pt.wikipedia.org/wiki/Pr%C3%AAmio_Quem_de_Melhor_Ator_Coadjuvante
# 503 Visitando (87/1000): https://pt.wikipedia.org/wiki/S%C3%A3o_Bento_do_Sapuca%C3%AD
# 504 Visitando (87/1000): https://pt.wikipedia.org/wiki/Transportes_no_estado_de_S%C3%A3o_Paulo
# 505 Visitando (87/1000): https://pt.wikipedia.org/wiki/Lista_de_munic%C3%ADpios_de_S%C3%A3o_Paulo_por_popula%C3%A7%C3%A3o
# 506 Visitando (89/1000): https://pt.wikipedia.org/wiki/Riol%C3%A2ndia507 Visitando (89/1000): https://pt.wikipedia.org/wiki/Turquia
# 508 Visitando (89/1000): https://pt.wikipedia.org/wiki/World_Bank_Group
# 509 Visitando (89/1000): https://pt.wikipedia.org/wiki/Tcheka
# 510 Visitando (89/1000): https://pt.wikipedia.org/wiki/Decauville
#
# 511 Visitando (89/1000): https://pt.wikipedia.org/wiki/Ilha_de_Man
# 512 Visitando (89/1000): https://pt.wikipedia.org/wiki/Rio_Jacar%C3%A9-Gua%C3%A7u
# 513 Visitando (89/1000): https://pt.wikipedia.org/wiki/Direito_do_trabalho
# 514 Visitando (89/1000): https://pt.wikipedia.org/wiki/Comunidade_Europeia_do_Carv%C3%A3o_e_do_A%C3%A7o
# 515 Visitando (89/1000): https://pt.wikipedia.org/wiki/Joseph_Weydemeyer
# 516 Visitando (89/1000): https://pt.wikipedia.org/wiki/Oswald_Avery
# 517 Visitando (89/1000): https://pt.wikipedia.org/wiki/Getas
# 518 Visitando (90/1000): https://pt.wikipedia.org/wiki/L%C3%ADngua_curda519 Visitando (90/1000): https://pt.wikipedia.org/wiki/Constantino_I
#
# 520 Visitando (90/1000): https://pt.wikipedia.org/wiki/E%C3%B3lios
# 521 Visitando (90/1000): https://pt.wikipedia.org/wiki/Gaziantepe_(prov%C3%ADncia)
# 522 Visitando (90/1000): https://pt.wikipedia.org/wiki/Lavrenty_Beria
# 523 Visitando (90/1000): https://pt.wikipedia.org/wiki/James_Dewar
# 524 Visitando (90/1000): https://pt.wikipedia.org/wiki/Campeonato_Mundial_de_Basquetebol_Masculino_de_2006
# 525 Visitando (90/1000): https://pt.wikipedia.org/wiki/Atat%C3%BCrk
# 526 Visitando (90/1000): https://pt.wikipedia.org/wiki/Nide_(prov%C3%ADncia)
# 527 Visitando (90/1000): https://pt.wikipedia.org/wiki/Greer_(Carolina_do_Sul)
# 528 Visitando (90/1000): https://pt.wikipedia.org/wiki/Curupira
# 529 Visitando (90/1000): https://pt.wikipedia.org/wiki/Plano_Quinquenal_(URSS)
# 530 Visitando (93/1000): https://pt.wikipedia.org/wiki/Kingsley_Amis
# 531 Visitando (93/1000): https://pt.wikipedia.org/wiki/Charles_Francis_Brush
# 532 Visitando (93/1000): https://pt.wikipedia.org/wiki/Constantino_III_(imperador_romano)
# 533 Visitando (93/1000): https://pt.wikipedia.org/wiki/Const%C3%A2ncio_III
# 534 Visitando (93/1000): https://pt.wikipedia.org/wiki/Reviravolta_de_Constantino
# 535 Visitando (93/1000): https://pt.wikipedia.org/wiki/Frente_Ocidental_(Primeira_Guerra_Mundial)
# 536 Visitando (93/1000): https://pt.wikipedia.org/wiki/Orgburo
# 537 Visitando (93/1000): https://pt.wikipedia.org/wiki/Fernando_I_da_Bulg%C3%A1ria
# 538 Visitando (93/1000): https://pt.wikipedia.org/wiki/Pr%C3%AAmio_Estatal_da_URSS
# 539 Visitando (93/1000): https://pt.wikipedia.org/wiki/M%C3%A9todo_de_ensino
# 540 Visitando (93/1000): https://pt.wikipedia.org/wiki/Pupieno
# 541 Visitando (93/1000): https://pt.wikipedia.org/wiki/Problemas_ambientais_no_Brasil
# 542 Visitando (99/1000): https://pt.wikipedia.org/wiki/L%C3%A2mpada_a_arco_voltaico
# 543 Visitando (99/1000): https://pt.wikipedia.org/wiki/Revolu%C3%A7%C3%A3o_Alem%C3%A3_de_1918-1919
# 544 Visitando (99/1000): https://pt.wikipedia.org/wiki/Grilagem
# 545 Visitando (99/1000): https://pt.wikipedia.org/wiki/Mogonc%C3%ADaco
# 546 Visitando (99/1000): https://pt.wikipedia.org/wiki/Artois
# 547 Visitando (99/1000): https://pt.wikipedia.org/wiki/Rizicultura
# 548 Visitando (99/1000): https://pt.wikipedia.org/wiki/Batalha_do_Lys
# 549 Visitando (99/1000): https://pt.wikipedia.org/wiki/Pal%C3%A1cio_Coburgo
# 550 Visitando (99/1000): https://pt.wikipedia.org/wiki/Flandres
# 551 Visitando (99/1000): https://pt.wikipedia.org/wiki/Viola%C3%A7%C3%A3o_da_B%C3%A9lgica
# 552 Visitando (99/1000): https://pt.wikipedia.org/wiki/Tornados_em_Santa_Catarina_em_2015
# 553 Visitando (99/1000): https://pt.wikipedia.org/wiki/Google_Inc.
# 554 Visitando (99/1000): https://pt.wikipedia.org/wiki/Quimioluminesc%C3%AAncia555 Visitando (99/1000): https://pt.wikipedia.org/wiki/Programa_de_computador
#
# 556 Visitando (99/1000): https://pt.wikipedia.org/wiki/Forragicultura
# 557 Visitando (99/1000): https://pt.wikipedia.org/wiki/Reino_Franco
# 558 Visitando (99/1000): https://pt.wikipedia.org/wiki/L%C3%A2mpada_de_arco_de_x%C3%A9non
# 559 Visitando (99/1000): https://pt.wikipedia.org/wiki/Estrada_Romana_do_Reno
# 560 Visitando (99/1000): https://pt.wikipedia.org/wiki/Peixoto_de_Azevedo
# 561 Visitando (99/1000): https://pt.wikipedia.org/wiki/Campinas
# 562 Visitando (99/1000): https://pt.wikipedia.org/wiki/C%C3%A9rebro_positr%C3%B4nico
# 563 Visitando (99/1000): https://pt.wikipedia.org/wiki/Anarquismo_p%C3%B3s-esquerdismo
# 564 Visitando (99/1000): https://pt.wikipedia.org/wiki/Rodovi%C3%A1ria_de_Lisboa
# 565 Visitando (99/1000): https://pt.wikipedia.org/wiki/Apedrejamento
# 566 Visitando (99/1000): https://pt.wikipedia.org/wiki/Grupo_Barraqueiro#421567 Visitando (99/1000): https://pt.wikipedia.org/wiki/Grupo_Escolar_Orosimbo_Maia
# 568 Visitando (99/1000): https://pt.wikipedia.org/wiki/Mafrense#217
#
# 569 Visitando (99/1000): https://pt.wikipedia.org/wiki/Emissoras_Pioneiras_de_Televis%C3%A3o
# 570 Visitando (99/1000): https://pt.wikipedia.org/wiki/Lista_de_peri%C3%B3dicos_anarquistas
# 571 Visitando (99/1000): https://pt.wikipedia.org/wiki/Bragado_(Buenos_Aires)
# 572 Visitando (99/1000): https://pt.wikipedia.org/wiki/Lista_de_carreiras_da_%C3%81rea_2_Carris_Metropolitana#2224
# 573 Visitando (99/1000): https://pt.wikipedia.org/wiki/Alphaville_(Campinas)
# 574 Visitando (99/1000): https://pt.wikipedia.org/wiki/Chevron
# 575 Visitando (99/1000): https://pt.wikipedia.org/wiki/Lista_de_carreiras_da_%C3%81rea_2_Carris_Metropolitana#2030
# 576 Visitando (99/1000): https://pt.wikipedia.org/wiki/Insurrei%C3%A7%C3%A3o
# 577 Visitando (99/1000): https://pt.wikipedia.org/wiki/Madhab
# 578 Visitando (99/1000): https://pt.wikipedia.org/wiki/Claude_Jarman_Jr.
# 579 Visitando (99/1000): https://pt.wikipedia.org/wiki/Pol%C3%ADtica_de_Gibraltar
# 580 Visitando (99/1000): https://pt.wikipedia.org/wiki/Sacco_and_Vanzetti
# 581 Visitando (99/1000): https://pt.wikipedia.org/wiki/Il%C3%ADada
# 582 Visitando (99/1000): https://pt.wikipedia.org/wiki/Esp%C3%A9cie_deficiente_de_dados
# 583 Visitando (99/1000): https://pt.wikipedia.org/wiki/Forbes
# 584 Visitando (99/1000): https://pt.wikipedia.org/wiki/Avenida_Salim_Farah_Maluf
# 585 Visitando (99/1000): https://pt.wikipedia.org/wiki/Joseph_Gurney_Cannon
# 586 Visitando (99/1000): https://pt.wikipedia.org/wiki/Urso-marsicano
# 587 Visitando (99/1000): https://pt.wikipedia.org/wiki/Campeonato_Russo_de_Futebol_de_2007
# 588 Visitando (99/1000): https://pt.wikipedia.org/wiki/The_New_York_Times_Best_Seller_list
# 589 Visitando (99/1000): https://pt.wikipedia.org/wiki/Petteri_Orpo
# 590 Visitando (102/1000): https://pt.wikipedia.org/wiki/Lone_Ranger
# 591 Visitando (102/1000): https://pt.wikipedia.org/wiki/Conforto
# 592 Visitando (102/1000): https://pt.wikipedia.org/wiki/Denis_Bezerra
# 593 Visitando (102/1000): https://pt.wikipedia.org/wiki/Sacramento
# 594 Visitando (102/1000): https://pt.wikipedia.org/wiki/Imigra%C3%A7%C3%A3o_nos_Estados_Unidos
# 595 Visitando (102/1000): https://pt.wikipedia.org/wiki/Avenida_Vereador_Jos%C3%A9_Diniz
# 596 Visitando (102/1000): https://pt.wikipedia.org/wiki/Lagoa_do_Taquaral
# 597 Visitando (102/1000): https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_da_Am%C3%A9rica_por_PIB_nominal
# 598 Visitando (102/1000): https://pt.wikipedia.org/wiki/Troca_de_popula%C3%A7%C3%B5es_entre_a_Gr%C3%A9cia_e_a_Turquia
# 599 Visitando (102/1000): https://pt.wikipedia.org/wiki/Ass%C3%ADncrona
# 600 Visitando (102/1000): https://pt.wikipedia.org/wiki/CIA
# 601 Visitando (102/1000): https://pt.wikipedia.org/wiki/Andrei_Kolmogorov
# 602 Visitando (104/1000): https://pt.wikipedia.org/wiki/Harvard_Business_School
# 603 Visitando (104/1000): https://pt.wikipedia.org/wiki/Treze_Col%C3%B4nias
# 604 Visitando (104/1000): https://pt.wikipedia.org/wiki/Andr%C3%A9_Weil
# 605 Visitando (104/1000): https://pt.wikipedia.org/wiki/Pris%C3%B5es_secretas_da_CIA
# 606 Visitando (104/1000): https://pt.wikipedia.org/wiki/Kiyoshi_Ito
# 607 Visitando (104/1000): https://pt.wikipedia.org/wiki/Cultura_mississipiana
# 608 Visitando (104/1000): https://pt.wikipedia.org/wiki/The_Lone_Ranger_(2013)
# 609 Visitando (104/1000): https://pt.wikipedia.org/wiki/Ponto_(regi%C3%A3o)
# 610 Visitando (104/1000): https://pt.wikipedia.org/wiki/Vault_7
# 611 Visitando (104/1000): https://pt.wikipedia.org/wiki/Lista_de_cavalos_not%C3%A1veis_do_western#Scout
# 612 Visitando (104/1000): https://pt.wikipedia.org/wiki/Pr%C3%AAmio_Wolf_de_Matem%C3%A1tica
# 613 Visitando (104/1000): https://pt.wikipedia.org/wiki/James_Forrestal
# 614 Visitando (106/1000): https://pt.wikipedia.org/wiki/Funda%C3%A7%C3%A3o_Wolf615 Visitando (106/1000): https://pt.wikipedia.org/wiki/Francisco_Pizarro
# 616 Visitando (106/1000): https://pt.wikipedia.org/wiki/Michael_Morley
#
# ...
# 5676 Visitando (983/1000): https://pt.wikipedia.org/wiki/RJ-104
# 5677 Visitando (983/1000): https://pt.wikipedia.org/wiki/Grand_Hustle_Records
# 5678 Visitando (984/1000): https://pt.wikipedia.org/wiki/Campeonato_Paranaense_de_Futebol_de_20095679 Visitando (984/1000): https://pt.wikipedia.org/wiki/Unidades_de_Planck
#
# 5680 Visitando (984/1000): https://pt.wikipedia.org/wiki/PMERJ
# 5681 Visitando (984/1000): https://pt.wikipedia.org/wiki/Kenta
# 5682 Visitando (984/1000): https://pt.wikipedia.org/wiki/Agente_inteligente
# 5683 Visitando (984/1000): https://pt.wikipedia.org/wiki/Kaja_Kallas
# 5684 Visitando (984/1000): https://pt.wikipedia.org/wiki/Jim_Clark
# 5685 Visitando (984/1000): https://pt.wikipedia.org/wiki/Wendel_Geraldo_Maur%C3%ADcio_e_Silva
# 5686 Visitando (984/1000): https://pt.wikipedia.org/wiki/Conta_Azul
# 5687 Visitando (984/1000): https://pt.wikipedia.org/wiki/Shane_Helms
# 5688 Visitando (984/1000): https://pt.wikipedia.org/wiki/Batalha_de_Konotop_(2022)
# 5689 Visitando (984/1000): https://pt.wikipedia.org/wiki/Nicolau_de_Autrecourt
# 5690 Visitando (986/1000): https://pt.wikipedia.org/wiki/A%C3%A7%C3%A3o_de_Einstein-Hilbert5691 Visitando (986/1000): https://pt.wikipedia.org/wiki/Takuma_Sato
# 5692 Visitando (986/1000): https://pt.wikipedia.org/wiki/Leg_drop#Slingshot_leg_drop
#
# 5693 Visitando (986/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_B%C3%A9lgica
# 5694 Visitando (986/1000): https://pt.wikipedia.org/wiki/Lista_de_deputados_estaduais_do_Rio_de_Janeiro_da_13.%C2%AA_legislatura
# 5695 Visitando (986/1000): https://pt.wikipedia.org/wiki/Lista_de_Grandes_Pr%C3%AAmios_de_F%C3%B3rmula_1
# 5696 Visitando (986/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Holanda_de_1960
# 5697 Visitando (986/1000): https://pt.wikipedia.org/wiki/Campeonato_Mundial_de_F%C3%B3rmula_1_de_1965
# 5698 Visitando (986/1000): https://pt.wikipedia.org/wiki/Ford_Cortina
# 5699 Visitando (986/1000): https://pt.wikipedia.org/wiki/Forte_de_Corjuem
# 5700 Visitando (986/1000): https://pt.wikipedia.org/wiki/G%C3%B6tz_Aly
# 5701 Visitando (986/1000): https://pt.wikipedia.org/wiki/Max_Lemos
# 5702 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Alemanha_de_19595703 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_de_Detroit_de_1983
#
# 5704 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_%C3%81frica_do_Sul_de_1983
# 5705 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Gr%C3%A3-Bretanha_de_1972
# 5706 Visitando (987/1000): https://pt.wikipedia.org/wiki/Ford_Model_K
# 5707 Visitando (987/1000): https://pt.wikipedia.org/wiki/Luca_Furbatto
# 5708 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Austr%C3%A1lia_de_1985
# 5709 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_It%C3%A1lia_de_2021
# 5710 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Fran%C3%A7a_de_1987
# 5711 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_B%C3%A9lgica_de_2021
# 5712 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Fran%C3%A7a_de_1996
# 5713 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_%C3%81ustria_de_1982
# 5714 Visitando (987/1000): https://pt.wikipedia.org/wiki/Toro_Rosso_STR75715 Visitando (987/1000): https://pt.wikipedia.org/wiki/Sauber_C17
# 5716 Visitando (987/1000): https://pt.wikipedia.org/wiki/Ford_EcoSport
#
# 5717 Visitando (987/1000): https://pt.wikipedia.org/wiki/McLaren_MP4/5
# 5718 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_do_M%C3%A9xico_de_1962
# 5719 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Hungria
# 5720 Visitando (987/1000): https://pt.wikipedia.org/wiki/Porsche_na_F%C3%B3rmula_1
# 5721 Visitando (987/1000): https://pt.wikipedia.org/wiki/Campeonato_Mundial_de_F%C3%B3rmula_1_de_2025
# 5722 Visitando (987/1000): https://pt.wikipedia.org/wiki/Pierre_Wach%C3%A9
# 5723 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_de_Detroit_de_1988
# 5724 Visitando (987/1000): https://pt.wikipedia.org/wiki/Toro_Rosso_STR10
# 5725 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_dos_Pa%C3%ADses_Baixos_de_1968
# 5726 Visitando (987/1000): https://pt.wikipedia.org/wiki/Onyx_ORE-25727 Visitando (987/1000): https://pt.wikipedia.org/wiki/Trojan%E2%80%93Tauranac_Racing
# 5728 Visitando (987/1000): https://pt.wikipedia.org/wiki/Williams_FW13
#
# 5729 Visitando (987/1000): https://pt.wikipedia.org/wiki/Lance_Reventlow
# 5730 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_B%C3%A9lgica_de_1970
# 5731 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Mal%C3%A1sia_de_2003
# 5732 Visitando (987/1000): https://pt.wikipedia.org/wiki/Circuito_de_Silverstone
# 5733 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_de_Detroit_(IndyCar)
# 5734 Visitando (987/1000): https://pt.wikipedia.org/wiki/Ford_Courier
# 5735 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Gr%C3%A3-Bretanha_de_1951
# 5736 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_de_M%C3%B4naco_de_2019
# 5737 Visitando (987/1000): https://pt.wikipedia.org/wiki/Mois%C3%A9s_Solana
# 5738 Visitando (987/1000): https://pt.wikipedia.org/wiki/Norisring5739 Visitando (987/1000): https://pt.wikipedia.org/wiki/Lista_dos_circuitos_da_Superleague_F%C3%B3rmula
# 5740 Visitando (987/1000): https://pt.wikipedia.org/wiki/Temporada_de_F%C3%B3rmula_1_de_2003
# 5741 Visitando (987/1000): https://pt.wikipedia.org/wiki/Scuderia_Corsa
#
# 5742 Visitando (987/1000): https://pt.wikipedia.org/wiki/Circuito_de_Paul_Ricard
# 5743 Visitando (987/1000): https://pt.wikipedia.org/wiki/Temporada_de_F%C3%B3rmula_1_de_1958
# 5744 Visitando (987/1000): https://pt.wikipedia.org/wiki/Otoni_de_Paula_Pai
# 5745 Visitando (987/1000): https://pt.wikipedia.org/wiki/Adrian_Sutil
# 5746 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_do_Brasil_de_2001
# 5747 Visitando (987/1000): https://pt.wikipedia.org/wiki/Sistema_de_Redu%C3%A7%C3%A3o_de_Arrasto
# 5748 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_B%C3%A9lgica_de_1958
# 5749 Visitando (987/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Gr%C3%A3-Bretanha_de_1953
# 5750 Visitando (988/1000): https://pt.wikipedia.org/wiki/Stuart_Lewis-Evans
# 5751 Visitando (988/1000): https://pt.wikipedia.org/wiki/Patrick_Lemari%C3%A9
# 5752 Visitando (988/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%A9mio_de_Portugal_de_1958
# 5753 Visitando (988/1000): https://pt.wikipedia.org/wiki/Ronda_6_de_2010_da_Superleague_F%C3%B3rmula
# 5754 Visitando (988/1000): https://pt.wikipedia.org/wiki/Luigi_Taramazzo
# 5755 Visitando (988/1000): https://pt.wikipedia.org/wiki/Dave_Redding
# 5756 Visitando (988/1000): https://pt.wikipedia.org/wiki/Pau-d%27Arco_(Tocantins)
# 5757 Visitando (988/1000): https://pt.wikipedia.org/wiki/Evangelhos_de_Lindisfarne
# 5758 Visitando (988/1000): https://pt.wikipedia.org/wiki/Tarrafal_(Santiago)
# 5759 Visitando (988/1000): https://pt.wikipedia.org/wiki/Duque_da_Normandia
# 5760 Visitando (988/1000): https://pt.wikipedia.org/wiki/Trimurti
# 5761 Visitando (988/1000): https://pt.wikipedia.org/wiki/Prazer
# 5762 Visitando (988/1000): https://pt.wikipedia.org/wiki/Varandinha_(Tarrafal)5763 Visitando (988/1000): https://pt.wikipedia.org/wiki/Benetton_B195
#
# 5764 Visitando (988/1000): https://pt.wikipedia.org/wiki/Igreja_Cat%C3%B3lica_na_Am%C3%A9rica_Latina
# 5765 Visitando (988/1000): https://pt.wikipedia.org/wiki/Universidade_Rey_Juan_Carlos
# 5766 Visitando (988/1000): https://pt.wikipedia.org/wiki/Campeonato_Ga%C3%BAcho_de_Futebol_de_2012_-_S%C3%A9rie_A
# 5767 Visitando (988/1000): https://pt.wikipedia.org/wiki/Alfa_Romeo_C43
# 5768 Visitando (988/1000): https://pt.wikipedia.org/wiki/Caz%C3%A8res
# 5769 Visitando (988/1000): https://pt.wikipedia.org/wiki/Parque_Barig%C3%BCi_(Curitiba)
# 5770 Visitando (988/1000): https://pt.wikipedia.org/wiki/Jos%C3%A9_Carlos_da_Costa_Ara%C3%BAjo
# 5771 Visitando (988/1000): https://pt.wikipedia.org/wiki/Filipa_da_Arm%C3%AAnia
# 5772 Visitando (988/1000): https://pt.wikipedia.org/wiki/Ramal_de_Piracicaba_(Companhia_Ytuana_de_Estradas_de_Ferro)
# 5773 Visitando (988/1000): https://pt.wikipedia.org/wiki/Minha_M%C3%A3e_%C3%A9_uma_Pe%C3%A7a_2
# 5774 Visitando (990/1000): https://pt.wikipedia.org/wiki/Igreja_Cat%C3%B3lica_na_Jamaica5775 Visitando (990/1000): https://pt.wikipedia.org/wiki/Rio_Branco_Atl%C3%A9tico_Clube_(ES)
#
# 5776 Visitando (990/1000): https://pt.wikipedia.org/wiki/Raimundo_IV_de_Tr%C3%ADpoli
# 5777 Visitando (990/1000): https://pt.wikipedia.org/wiki/Edu_Manga
# 5778 Visitando (990/1000): https://pt.wikipedia.org/wiki/Recoleta
# 5779 Visitando (990/1000): https://pt.wikipedia.org/wiki/Lei_Lerdo
# 5780 Visitando (990/1000): https://pt.wikipedia.org/wiki/Slammiversary_XI
# 5781 Visitando (990/1000): https://pt.wikipedia.org/wiki/Castle_(s%C3%A9rie_de_televis%C3%A3o)
# 5782 Visitando (990/1000): https://pt.wikipedia.org/wiki/Ultimate_Ultimate_1996
# 5783 Visitando (990/1000): https://pt.wikipedia.org/wiki/Morto-vivo
# 5784 Visitando (990/1000): https://pt.wikipedia.org/wiki/Brasil_nos_Jogos_Ol%C3%ADmpicos_de_Ver%C3%A3o_de_1976
# 5785 Visitando (990/1000): https://pt.wikipedia.org/wiki/Grande_Pr%C3%AAmio_da_Hungria_de_2006
# 5786 Visitando (991/1000): https://pt.wikipedia.org/wiki/Jos%C3%A9_Silvio_Fiolo
# 5787 Visitando (991/1000): https://pt.wikipedia.org/wiki/Lista_de_governadores_do_Distrito_Federal
# 5788 Visitando (991/1000): https://pt.wikipedia.org/wiki/M%C3%BAsica_da_Tun%C3%ADsia
# 5789 Visitando (991/1000): https://pt.wikipedia.org/wiki/Tarqu%C3%ADnio,_o_Soberbo
# 5790 Visitando (991/1000): https://pt.wikipedia.org/wiki/Batalha_de_Canas
# 5791 Visitando (991/1000): https://pt.wikipedia.org/wiki/Itaipava_do_Graja%C3%BA
# 5792 Visitando (991/1000): https://pt.wikipedia.org/wiki/Gabriel_Medina
# 5793 Visitando (991/1000): https://pt.wikipedia.org/wiki/Amanita_muscaria
# 5794 Visitando (991/1000): https://pt.wikipedia.org/wiki/Radioqu%C3%ADmica
# 5795 Visitando (991/1000): https://pt.wikipedia.org/wiki/Super_Copa_Gr%C3%A3o-Par%C3%A1
# 5796 Visitando (991/1000): https://pt.wikipedia.org/wiki/Narcisismo_vulner%C3%A1vel
# 5797 Visitando (991/1000): https://pt.wikipedia.org/wiki/Juniano_Justino
# 5798 Visitando (992/1000): https://pt.wikipedia.org/wiki/Batalha_de_C%C3%A1pua_(212_a.C.)
# 5799 Visitando (992/1000): https://pt.wikipedia.org/wiki/Cerco_de_Iliturgi
# 5800 Visitando (992/1000): https://pt.wikipedia.org/wiki/Geografia_da_Tun%C3%ADsia
# 5801 Visitando (992/1000): https://pt.wikipedia.org/wiki/Duplo_envolvimento
# 5802 Visitando (992/1000): https://pt.wikipedia.org/wiki/Lamela_(micologia)
# 5803 Visitando (992/1000): https://pt.wikipedia.org/wiki/Marco_Min%C3%BAcio_Rufo
# 5804 Visitando (992/1000): https://pt.wikipedia.org/wiki/World_Surf_League_de_2018
# 5805 Visitando (992/1000): https://pt.wikipedia.org/wiki/Batalha_de_Ilipa
# 5806 Visitando (992/1000): https://pt.wikipedia.org/wiki/Amanita_pantherina
# 5807 Visitando (992/1000): https://pt.wikipedia.org/wiki/Jordy_Smith
# 5808 Visitando (992/1000): https://pt.wikipedia.org/wiki/Itapo%C3%A3_(Vila_Velha)
# 5809 Visitando (992/1000): https://pt.wikipedia.org/wiki/Galibis
# 5810 Visitando (993/1000): https://pt.wikipedia.org/wiki/Medenine
# 5811 Visitando (993/1000): https://pt.wikipedia.org/wiki/Santo_Tom%C3%A9_(Ja%C3%A9n)
# 5812 Visitando (993/1000): https://pt.wikipedia.org/wiki/Ditadura_de_F%C3%A1bio_M%C3%A1ximo#Ditadura_dupla
# 5813 Visitando (993/1000): https://pt.wikipedia.org/wiki/Monastir_(prov%C3%ADncia)
# 5814 Visitando (993/1000): https://pt.wikipedia.org/wiki/Batalha_de_St._Vith
# 5815 Visitando (993/1000): https://pt.wikipedia.org/wiki/Brasinca
# 5816 Visitando (993/1000): https://pt.wikipedia.org/wiki/Eu_Sempre_Fui_Sincero,_Voc%C3%AA_Sabe_Muito_Bem
# 5817 Visitando (993/1000): https://pt.wikipedia.org/wiki/Pascal_Roller
# 5818 Visitando (993/1000): https://pt.wikipedia.org/wiki/Encapsulamento
# 5819 Visitando (993/1000): https://pt.wikipedia.org/wiki/People_Will_Talk
# 5820 Visitando (993/1000): https://pt.wikipedia.org/wiki/Esp%C3%ADrito_Santo
# 5821 Visitando (993/1000): https://pt.wikipedia.org/wiki/Linha_de_baixo
# 5822 Visitando (994/1000): https://pt.wikipedia.org/wiki/J%C3%B3dar5823 Visitando (994/1000): https://pt.wikipedia.org/wiki/Chiclana_de_Segura
#
# 5824 Visitando (994/1000): https://pt.wikipedia.org/wiki/Pick-Up
# 5825 Visitando (994/1000): https://pt.wikipedia.org/wiki/Rio_Arno
# 5826 Visitando (994/1000): https://pt.wikipedia.org/wiki/Conjunto_musical
# 5827 Visitando (994/1000): https://pt.wikipedia.org/wiki/Cl%C3%A9o_Pires
# 5828 Visitando (994/1000): https://pt.wikipedia.org/wiki/Lagoa_de_Praia_(Rio_Tinto)
# 5829 Visitando (994/1000): https://pt.wikipedia.org/wiki/Theatinerkirche
# 5830 Visitando (994/1000): https://pt.wikipedia.org/wiki/Ewan_McGregor
# 5831 Visitando (994/1000): https://pt.wikipedia.org/wiki/Pantanal
# 5832 Visitando (994/1000): https://pt.wikipedia.org/wiki/Centro_de_Pesquisa_do_C%C3%A2ncer_da_Alemanha
# 5833 Visitando (994/1000): https://pt.wikipedia.org/wiki/Lista_de_patrim%C3%B3nio_edificado_no_distrito_de_Braga
# 5834 Visitando (996/1000): https://pt.wikipedia.org/wiki/Castelo_de_Faria
# 5835 Visitando (996/1000): https://pt.wikipedia.org/wiki/Parada_de_Bouro
# 5836 Visitando (996/1000): https://pt.wikipedia.org/wiki/Patag%C3%B3nia
# 5837 Visitando (996/1000): https://pt.wikipedia.org/wiki/Castelo_da_D._Chica
# 5838 Visitando (996/1000): https://pt.wikipedia.org/wiki/Nogueira_(Braga)
# 5839 Visitando (996/1000): https://pt.wikipedia.org/wiki/Quinti%C3%A3es
# 5840 Visitando (996/1000): https://pt.wikipedia.org/wiki/Honda_Ridgeline
# 5841 Visitando (996/1000): https://pt.wikipedia.org/wiki/Prov%C3%ADncia_da_Eritreia
# 5842 Visitando (996/1000): https://pt.wikipedia.org/wiki/Contraofensiva_de_Carc%C3%B3via_(2022)
# 5843 Visitando (996/1000): https://pt.wikipedia.org/wiki/Marlos_Moreno
# 5844 Visitando (996/1000): https://pt.wikipedia.org/wiki/Mois%C3%A9s_Villarroel
# 5845 Visitando (996/1000): https://pt.wikipedia.org/wiki/Condado_de_Cayuga
# 5846 Visitando (998/1000): https://pt.wikipedia.org/wiki/Esta%C3%A7%C3%A3o_de_Tamel
# 5847 Visitando (998/1000): https://pt.wikipedia.org/wiki/Carvalhos
# 5848 Visitando (998/1000): https://pt.wikipedia.org/wiki/Honda_Logo
# 5849 Visitando (998/1000): https://pt.wikipedia.org/wiki/Honda_Amaze
# 5850 Visitando (998/1000): https://pt.wikipedia.org/wiki/Wii_(s%C3%A9rie)
# 5851 Visitando (998/1000): https://pt.wikipedia.org/wiki/Ass%C3%A1raco
# 5852 Visitando (998/1000): https://pt.wikipedia.org/wiki/Abdol_Hossein_Sardari
# 5853 Visitando (998/1000): https://pt.wikipedia.org/wiki/Creonte
# 5854 Visitando (998/1000): https://pt.wikipedia.org/wiki/Lista_de_vice-presidentes_do_Brasil
# 5855 Visitando (998/1000): https://pt.wikipedia.org/wiki/Andrew_Lloyd_Webber
# 5856 Visitando (998/1000): https://pt.wikipedia.org/wiki/Tratado_sobre_a_Proibi%C3%A7%C3%A3o_das_Armas_Nucleares
# 5857 Visitando (998/1000): https://pt.wikipedia.org/wiki/Ciclone_barotr%C3%B3pico
# 5858 Visitando (998/1000): https://pt.wikipedia.org/wiki/Polinice
# 5859 Visitando (998/1000): https://pt.wikipedia.org/wiki/Wilkie_Collins
# 5860 Visitando (998/1000): https://pt.wikipedia.org/wiki/WTA_de_Cluj-Napoca
# 5861 Visitando (998/1000): https://pt.wikipedia.org/wiki/Agents_of_S.H.I.E.L.D._(5.%C2%AA_temporada)#ep99
# 5862 Visitando (998/1000): https://pt.wikipedia.org/wiki/Ne_Zha_2
# 5863 Visitando (998/1000): https://pt.wikipedia.org/wiki/Orestes
# 5864 Visitando (998/1000): https://pt.wikipedia.org/wiki/Zequinha_(futebolista)
# 5865 Visitando (998/1000): https://pt.wikipedia.org/wiki/Patos_(Alb%C3%A2nia)
# 5866 Visitando (998/1000): https://pt.wikipedia.org/wiki/Alberto_Moreno_P%C3%A9rez
# 5867 Visitando (998/1000): https://pt.wikipedia.org/wiki/Atentados_de_11_de_mar%C3%A7o_de_2004_em_Madrid
# 5868 Visitando (998/1000): https://pt.wikipedia.org/wiki/This_Is_America
# 5869 Visitando (998/1000): https://pt.wikipedia.org/wiki/Final_da_Copa_do_Brasil_de_Futebol_de_2022
# Coletadas 1001 páginas de pessoas em 5869 visitas.

# %%
import os
from bs4 import BeautifulSoup
from collections import defaultdict, deque

PASTA = "wikipedia_pessoas"

# dicionários pra guardar nomes/links
nomes_para_links = {}
links_para_nomes = {}

# aqui vai ficar o grafo, cada pessoa tem um conjunto de conexões
arestas = defaultdict(set)

def normalizar_href(href):
    # tira pedaços tipo # e ? do link e deixa minúsculo
    href = href.split("#")[0]
    href = href.split("?")[0]
    return href.strip().lower()


# primeira passada: pegar nome e link canônico de cada pessoa
for arq in os.listdir(PASTA):
    if not arq.endswith(".html"):  # só entra em arquivos html
        continue

    caminho = os.path.join(PASTA, arq)
    html = open(caminho, "r", encoding="utf-8").read()
    sopa = BeautifulSoup(html, "html.parser")

    # título da página (nome da pessoa)
    titulo = sopa.find("h1", id="firstHeading")
    if not titulo:
        continue
    nome = titulo.text.strip()

    # procura o link oficial da wiki dessa pessoa
    link_a = None
    for a in sopa.select("link[rel=canonical]"):
        href = a.get("href")
        if href and "/wiki/" in href:
            link_a = href[href.find("/wiki/"):]
            break

    # salva nome/link
    if link_a:
        link_a = normalizar_href(link_a)
        nomes_para_links[nome] = link_a
        links_para_nomes[link_a] = nome


# montar as conexões do grafo
for arq in os.listdir(PASTA):
    if not arq.endswith(".html"):
        continue

    caminho = os.path.join(PASTA, arq)
    html = open(caminho, "r", encoding="utf-8").read()
    sopa = BeautifulSoup(html, "html.parser")

    titulo = sopa.find("h1", id="firstHeading")
    if not titulo:
        continue
    nome_a = titulo.text.strip()

    # pega todos os links dessa página
    for a in sopa.find_all("a", href=True):
        href = a["href"]
        # só pega links que são de wiki e não tem namespace tipo "Categoria:"
        if not href.startswith("/wiki/") or ":" in href:
            continue
        href = normalizar_href(href)

        # vê se esse link corresponde a alguém do nosso banco
        nome_b = links_para_nomes.get(href)
        if nome_b and nome_b != nome_a:
            # cria aresta nome_a -> nome_b
            arestas[nome_a].add(nome_b)


# mostra um resumo do grafo
print("Grafo construído:", len(nomes_para_links), "pessoas,", sum(len(v) for v in arestas.values()), "conexões.")
# Out:
# Grafo construído: 994 pessoas, 2155 conexões.

# %%
# INTERFACE

# função auxiliar: tenta casar o nome digitado com o banco
def encontrar_nome(nome_digitado):
     # deixa tudo minúsculo e sem espaço no começo/fim
    nome_digitado = nome_digitado.lower().strip()
    
    # primeira tentativa: acha exato
    for nome in nomes_para_links.keys():
        if nome.lower() == nome_digitado:
            return nome
    
    # se não achou exato, tenta achar parcial (contendo a string)
    for nome in nomes_para_links.keys():
        if nome_digitado in nome.lower():
            return nome
    
    # se não achou nada, retorna None
    return None

# interface
# pede pra digitar a pessoa de origem e destino
pessoa_origem_in = input("Nome da pessoa de origem: ").strip()
pessoa_destino_in = input("Nome da pessoa de destino: ").strip()

# tenta casar os nomes digitados com os nomes que temos
pessoa_origem = encontrar_nome(pessoa_origem_in)
pessoa_destino = encontrar_nome(pessoa_destino_in)

# se não achou uma das pessoas
if not pessoa_origem or not pessoa_destino:
    print(" ❌ Não encontrei uma ou ambas as pessoas no banco coletado.")
else:
    # usa a função BFS pra achar o menor caminho (grau de separação)
    caminho = menor_caminho_bfs(arestas, pessoa_origem, pessoa_destino)
    
    # se não achou caminho
    if caminho is None:
        print(" ⚠️ Não há conexão encontrada entre as pessoas informadas.")
    else:
        # se achou, calcula grau de separação (quantos passos)
        graus = len(caminho) - 1
        print(f"\n✅ Grau de separação entre '{pessoa_origem}' e '{pessoa_destino}': {graus}")
        print("Caminho encontrado:")
        
        # mostra passo a passo
        for i, pessoa in enumerate(caminho):
            if i == 0:
                print(f"   {pessoa} (origem)")      # primeira pessoa
            elif i == len(caminho) - 1:
                print(f"   {pessoa} (destino)")    # última pessoa
            else:
                print(f"   {pessoa}")              # pessoas intermediárias
# Out:
# ✅ Grau de separação entre 'Henrique III de Castela' e 'Henrique V de Inglaterra': 3
# Caminho encontrado:
#    Henrique III de Castela (origem)
#    Filipe II de Espanha
#    Henrique VIII de Inglaterra
#    Henrique V de Inglaterra (destino)
